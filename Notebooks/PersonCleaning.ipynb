# %% [markdown]
# ## FARS Data Format (Person file)

# %%
#Load dependencies
import os
import pandas as pd

# %%
# Path to files
person_2018 = os.path.join("..", "Raw_files","FARS2018NationalCSV", "PERSON.csv")
person_2017 = os.path.join("..", "Raw_files","FARS2017NationalCSV", "PERSON.csv")
person_2016 = os.path.join("..", "Raw_files","FARS2016NationalCSV", "PERSON.csv")
person_2015 = os.path.join("..", "Raw_files","FARS2015NationalCSV", "PERSON.csv")
person_2014 = os.path.join("..", "Raw_files","FARS2014NationalCSV", "PERSON.csv")
person_2013 = os.path.join("..", "Raw_files","FARS2013NationalCSV", "PERSON.csv")
person_2012 = os.path.join("..", "Raw_files","FARS2012NationalCSV", "PERSON.csv")
person_2011 = os.path.join("..", "Raw_files","FARS2011NationalCSV", "PERSON.csv")
person_2010 = os.path.join("..", "Raw_files","FARS2010NationalCSV", "PERSON.csv")
person_2009 = os.path.join("..", "Raw_files","FARS2009NationalCSV", "PERSON.csv")
person_2008 = os.path.join("..", "Raw_files","FARS2008NationalCSV", "PERSON.csv")
person_2007 = os.path.join("..", "Raw_files","FARS2007NationalCSV", "PERSON.csv")
person_2006 = os.path.join("..", "Raw_files","FARS2006NationalCSV", "PERSON.csv")
person_2005 = os.path.join("..", "Raw_files","FARS2005NationalCSV", "PERSON.csv")
person_2004 = os.path.join("..", "Raw_files","FARS2004NationalCSV", "PERSON.csv")
person_2003 = os.path.join("..", "Raw_files","FARS2003NationalCSV", "PERSON.csv")
person_2002 = os.path.join("..", "Raw_files","FARS2002NationalCSV", "PERSON.csv")
person_2001 = os.path.join("..", "Raw_files","FARS2001NationalCSV", "PERSON.csv")
person_2000 = os.path.join("..", "Raw_files","FARS2000NationalCSV", "PERSON.csv")
person_1999 = os.path.join("..", "Raw_files","FARS1999NationalCSV", "PERSON.csv")
person_1998 = os.path.join("..", "Raw_files","FARS1998NationalCSV", "PERSON.csv")

# %%
# Read csv
person_2018_df=pd.read_csv(person_2018)
person_2017_df=pd.read_csv(person_2017)
person_2016_df=pd.read_csv(person_2016)
person_2015_df=pd.read_csv(person_2015)
person_2014_df=pd.read_csv(person_2014)
person_2013_df=pd.read_csv(person_2013)
person_2012_df=pd.read_csv(person_2012)
person_2011_df=pd.read_csv(person_2011)
person_2010_df=pd.read_csv(person_2010)
person_2009_df=pd.read_csv(person_2009)
person_2008_df=pd.read_csv(person_2008)
person_2007_df=pd.read_csv(person_2007)
person_2006_df=pd.read_csv(person_2006)
person_2005_df=pd.read_csv(person_2005)
person_2004_df=pd.read_csv(person_2004)
person_2003_df=pd.read_csv(person_2003)
person_2002_df=pd.read_csv(person_2002)
person_2001_df=pd.read_csv(person_2001)
person_2000_df=pd.read_csv(person_2000)
person_1999_df=pd.read_csv(person_1999)
person_1998_df=pd.read_csv(person_1998)

# %%
person_2018_df.head(1)
# Out:
#    STATE  ST_CASE  VE_FORMS  VEH_NO  PER_NO  STR_VEH  COUNTY  DAY  MONTH  \
# 0      1    10001         1       1       1        0     121    5      1
#
#    HOUR  ...  DEATH_TM  LAG_HRS  LAG_MINS  P_SF1  P_SF2  P_SF3  WORK_INJ  \
# 0     6  ...       600        0         0      0      0      0         1
#
#    HISPANIC  RACE  LOCATION
# 0         7     2         0
#
# [1 rows x 62 columns]

# %%
# Use only given attributes
person_2018_final = person_2018_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2017_final = person_2017_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2016_final = person_2016_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2015_final = person_2015_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2014_final = person_2014_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2013_final = person_2013_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2012_final = person_2012_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2011_final = person_2011_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2010_final = person_2010_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'REST_MIS', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2009_final = person_2009_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2008_final = person_2008_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2007_final = person_2007_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2006_final = person_2006_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2005_final = person_2005_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2004_final = person_2004_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2003_final = person_2003_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2002_final = person_2002_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2001_final = person_2001_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'DOA', 'HOSPITAL']]
person_2000_final = person_2000_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'HOSPITAL']]
person_1999_final = person_1999_df[['ST_CASE', 'AGE', 'SEX', 'RACE', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'HOSPITAL']]
person_1998_final = person_1998_df[['ST_CASE', 'AGE', 'SEX', 'REST_USE', 'INJ_SEV', 'EJECTION', 'DRINKING', 'ALC_RES', 'DRUGS', 'HOSPITAL']]

# %%
# Export to csv
person_2018_final.to_csv(r'../Cleaned/Person/person_2018.csv', index=False, header=True)
person_2017_final.to_csv(r'../Cleaned/Person/person_2017.csv', index=False, header=True)
person_2016_final.to_csv(r'../Cleaned/Person/person_2016.csv', index=False, header=True)
person_2015_final.to_csv(r'../Cleaned/Person/person_2015.csv', index=False, header=True)
person_2014_final.to_csv(r'../Cleaned/Person/person_2014.csv', index=False, header=True)
person_2013_final.to_csv(r'../Cleaned/Person/person_2013.csv', index=False, header=True)
person_2012_final.to_csv(r'../Cleaned/Person/person_2012.csv', index=False, header=True)
person_2011_final.to_csv(r'../Cleaned/Person/person_2011.csv', index=False, header=True)
person_2010_final.to_csv(r'../Cleaned/Person/person_2010.csv', index=False, header=True)
person_2009_final.to_csv(r'../Cleaned/Person/person_2009.csv', index=False, header=True)
person_2008_final.to_csv(r'../Cleaned/Person/person_2008.csv', index=False, header=True)
person_2007_final.to_csv(r'../Cleaned/Person/person_2007.csv', index=False, header=True)
person_2006_final.to_csv(r'../Cleaned/Person/person_2006.csv', index=False, header=True)
person_2005_final.to_csv(r'../Cleaned/Person/person_2005.csv', index=False, header=True)
person_2004_final.to_csv(r'../Cleaned/Person/person_2004.csv', index=False, header=True)
person_2003_final.to_csv(r'../Cleaned/Person/person_2003.csv', index=False, header=True)
person_2002_final.to_csv(r'../Cleaned/Person/person_2002.csv', index=False, header=True)
person_2001_final.to_csv(r'../Cleaned/Person/person_2001.csv', index=False, header=True)
person_2000_final.to_csv(r'../Cleaned/Person/person_2000.csv', index=False, header=True)
person_1999_final.to_csv(r'../Cleaned/Person/person_1999.csv', index=False, header=True)
person_1998_final.to_csv(r'../Cleaned/Person/person_1998.csv', index=False, header=True)
