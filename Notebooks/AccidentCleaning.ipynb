# %%
import pandas as pd
import os

# %%
## Read in Accident CSV file
file = os.path.join("..","Raw_files", "FARS1998NationalCSV","ACCIDENT.csv")

# %%
# create dataFrame and load in data from CSV file
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
## Create a new dataFrame for just Texas cases since data is over 100k rows
tx_df = df.loc[df['STATE'] == 48]
# tx_df.head()

# %%
# tx_df.columns

# %%
## Dropping Unneccesary Columns
clean = tx_df.drop(columns=['STATE', 'VE_FORMS',  'PEDS', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MINUTE', 'NHS', 'ROUTE', 'TWAY_ID',  'MILEPT', 'SP_JUR', 
    'HARM_EV', 'MAN_COLL',  'REL_ROAD', 'LGT_COND', 'SCH_BUS', 'RAIL', 'NOT_HOUR', 'NOT_MIN', 'ARR_HOUR','ARR_MIN', 'HOSP_HR', 'HOSP_MN', 'CF1', 'CF2', 'CF3', 'FATALS','DRUNK_DR', 'ROAD_FNC',
                           'REL_JUNC', 'TRAF_FLO', 'NO_LANES', 'SP_LIMIT','ALIGNMNT', 'PROFILE', 'PAVE_TYP', 'SUR_COND', 'TRA_CONT', 'T_CONT_F',
                           'HIT_RUN','C_M_ZONE'])
# 'RUR_URB', 'FUNC_SYS','RD_OWNER','PVH_INVL','PERNOTMVIT', 'PERMVIT','RELJCT1', 'RELJCT2','WRK_ZONE','WEATHER1', 'WEATHER2','VE_TOTAL','TWAY_ID2',
# clean.head()

# %%
## Check new DF to ensure file read accurately
clean
# Out:
#        MONTH  HOUR  WEATHER  DAY_WEEK  ST_CASE  YEAR
# 31028      1     3        2         5   480001  1998
# 31029      1     0        1         5   480002  1998
# 31030      1    18        1         5   480003  1998
# 31031      1     5        2         5   480004  1998
# 31032      1     2        1         5   480005  1998
# 31033      1    13        1         5   480006  1998
# 31034      1     4        1         6   480007  1998
# 31035      1    11        2         6   480008  1998
# 31036      1    23        1         6   480009  1998
# 31037      1    18        1         7   480010  1998
# 31038      1    14        1         7   480011  1998
# 31039      1    20        1         7   480012  1998
# 31040      1    18        1         7   480013  1998
# 31041      1     2        1         7   480014  1998
# 31042      1    18        1         7   480015  1998
# 31043      1    22        1         7   480016  1998
# 31044      1     0        1         1   480017  1998
# ...

# %%
## Create new CSV with cleaned TX data
clean.to_csv('../Cleaned/Accident/1998_Accident.csv', index=False)
