# %% [markdown]
# Formatting for Charts

# %%
import os
import pandas as pd

# %%
# Import MASTER merged
master = os.path.join("..","..", "Cleaned","MASTER_merged.csv")

# %%
# Read imported files
master_df=pd.read_csv(master)

# %%
# Display df
master_df
# Out:
#        Unnamed: 0  ST_CASE  PERSONS  COUNTY  CITY  DAY  MONTH  YEAR  DAY_WEEK  \
# 0               0   480024        2       7     0    4      1  2018         5
# 1               1   480024        2       7     0    4      1  2018         5
# 2               2   480041        3     439   260    5      1  2018         6
# 3               4   480041        3     439   260    5      1  2018         6
# 4               5   480044        2      27  3690    6      1  2018         7
# ...           ...      ...      ...     ...   ...  ...    ...   ...       ...
# 13421         302   483068        1     141  2190   19     12  1998         7
# 13422         303   483113        2     201     0    7     10  1998         4
# 13423         304   483113        2     201     0    7     10  1998         4
# 13424         305   483167        3     113  2590   10      7  1998         6
# 13425         306   483167        3     113  2590   10      7  1998         6
#
#        HOUR  ...  ALIGNMNT  PROFILE PAVE_TYP SUR_COND  TRA_CONT  T_CONT_F  \
# 0        18  ...       NaN      NaN      NaN      NaN       NaN       NaN
# 1        18  ...       NaN      NaN      NaN      NaN       NaN       NaN
# 2        20  ...       NaN      NaN      NaN      NaN       NaN       NaN
# 3        20  ...       NaN      NaN      NaN      NaN       NaN       NaN
# 4        20  ...       NaN      NaN      NaN      NaN       NaN       NaN
# ...     ...  ...       ...      ...      ...      ...       ...       ...
# 13421    21  ...       1.0      1.0      2.0      1.0       0.0       0.0
# 13422    13  ...       1.0      1.0      1.0      1.0       0.0       0.0
# 13423    13  ...       1.0      1.0      1.0      1.0       0.0       0.0
# 13424    21  ...       1.0      1.0      2.0      1.0       0.0       0.0
# 13425    21  ...       1.0      1.0      2.0      1.0       0.0       0.0
#
#        HIT_RUN  C_M_ZONE  latitude  longitud
# 0          NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...
# 13421      0.0       0.0       NaN       NaN
# 13422      0.0       0.0       NaN       NaN
# 13423      0.0       0.0       NaN       NaN
# 13424      0.0       0.0       NaN       NaN
# 13425      0.0       0.0       NaN       NaN
#
# [13426 rows x 51 columns]

# %%
# Show df columns
master_df.columns
# Out:
# Index(['Unnamed: 0', 'ST_CASE', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MONTH',
#        'YEAR', 'DAY_WEEK', 'HOUR', 'MINUTE', 'ROUTE', 'TWAY_ID', 'TWAY_ID2',
#        'LATITUDE', 'LONGITUD', 'TYP_INT', 'WEATHER1', 'WEATHER2', 'WEATHER',
#        'CF1', 'CF2', 'CF3', 'FATALS', 'AGE', 'SEX', 'REST_USE', 'INJ_SEV',
#        'DRINKING', 'DRUGS', 'PER_TYP', 'TRAV_SP', 'PREV_ACC', 'PREV_DWI',
#        'PREV_SPD', 'Year', 'ROAD_FNC', 'REL_JUNC', 'TRAF_FLO', 'NO_LANES',
#        'SP_LIMIT', 'ALIGNMNT', 'PROFILE', 'PAVE_TYP', 'SUR_COND', 'TRA_CONT',
#        'T_CONT_F', 'HIT_RUN', 'C_M_ZONE', 'latitude', 'longitud'],
#       dtype='object')

# %%
# Show unique values
master_df.WEATHER.unique()
# Out:
# array([ 1, 10,  2,  8, 99,  5,  6,  7, 98,  4,  9,  3], dtype=int64)

# %%
# Show unique values
master_df.TYP_INT.unique()
# Out:
# array([ 2.,  1.,  3.,  4., 10., 98.,  5.,  7.,  6., nan])

# %%
# Change values in Weather column
master_df.WEATHER[master_df.WEATHER == 1] = 'Clear'
master_df.WEATHER[master_df.WEATHER == 10] = 'Other'
master_df.WEATHER[master_df.WEATHER == 2] = 'Other'
master_df.WEATHER[master_df.WEATHER == 8] = 'Other'
master_df.WEATHER[master_df.WEATHER == 5] = 'Other'
master_df.WEATHER[master_df.WEATHER == 99] = 'Other'
master_df.WEATHER[master_df.WEATHER == 6] = 'Other'
master_df.WEATHER[master_df.WEATHER == 7] = 'Other'
master_df.WEATHER[master_df.WEATHER == 98] = 'Other'
master_df.WEATHER[master_df.WEATHER == 4] = 'Other'
master_df.WEATHER[master_df.WEATHER == 9] = 'Other'
master_df.WEATHER[master_df.WEATHER == 3] = 'Other'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
master_df.WEATHER.unique()
# Out:
# array(['Clear', 'Other'], dtype=object)

# %%
# Change values in TYPE_INT column
master_df.TYP_INT[master_df.TYP_INT == 1.0] = 'No Intersection'
master_df.TYP_INT[master_df.TYP_INT == 2.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 3.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 4.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 10.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 98.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 5.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 7.0] = 'Intersection'
master_df.TYP_INT[master_df.TYP_INT == 6.0] = 'Intersection'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
master_df.TYP_INT.unique()
# Out:
# array(['Intersection', 'No Intersection', nan], dtype=object)

# %%
master_df.INJ_SEV.unique()
# Out:
# array([4, 0, 1, 3, 2, 9], dtype=int64)

# %%
# Change values in INJ_SEV column
master_df.INJ_SEV[master_df.INJ_SEV == 4] = 'Fatal'
master_df.INJ_SEV[master_df.INJ_SEV == 0] = 'Minor'
master_df.INJ_SEV[master_df.INJ_SEV == 1] = 'Minor'
master_df.INJ_SEV[master_df.INJ_SEV == 2] = 'Minor'
master_df.INJ_SEV[master_df.INJ_SEV == 3] = 'Severe'
master_df.INJ_SEV[master_df.INJ_SEV == 9] = 'Unknown'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
master_df.INJ_SEV.unique()
# Out:
# array(['Fatal', 'Minor', 'Severe', 'Unknown'], dtype=object)

# %%
# Make df with only Fatal type of 'injury severity'
master_fatal = master_df.loc[master_df['INJ_SEV'] == 'Fatal']

# %%
master_df.INJ_SEV.unique()
# Out:
# array(['Fatal', 'Minor', 'Severe', 'Unknown'], dtype=object)

# %%
master_df.WEATHER.unique()
# Out:
# array(['Clear', 'Other'], dtype=object)

# %%
master_df.TYP_INT.unique()
# Out:
# array(['Intersection', 'No Intersection', nan], dtype=object)

# %%
master_df.DAY_WEEK.unique()
# Out:
# array([5, 6, 7, 1, 3, 4, 2], dtype=int64)

# %%
# Change values in day_week column
master_df.DAY_WEEK[master_df.DAY_WEEK == 1] = 'Sunday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 2] = 'Monday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 3] = 'Tuesday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 4] = 'Wednesday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 5] = 'Thursday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 6] = 'Friday'
master_df.DAY_WEEK[master_df.DAY_WEEK == 7] = 'Saturday'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
master_df.REST_USE.unique()
# Out:
# array([19,  3, 17, 29, 20, 98, 99,  1,  7,  0, 97,  2, 16,  5, 15,  8],
#       dtype=int64)

# %%
# Change values in rest_use column
master_df.REST_USE[master_df.REST_USE == 19] = 'Helmet'
master_df.REST_USE[master_df.REST_USE == 17] = 'No Helmet'
master_df.REST_USE[master_df.REST_USE == 29] = 'Unknown'
master_df.REST_USE[master_df.REST_USE == 20] = 'No Helmet'
master_df.REST_USE[master_df.REST_USE == 16] = 'Helmet'
master_df.REST_USE[master_df.REST_USE == 5] = 'Helmet'
master_df.REST_USE[master_df.REST_USE == 15] = 'No Helmet'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
master_df.REST_USE.unique()
# Out:
# array(['Helmet', 3, 'No Helmet', 'Unknown', 98, 99, 1, 7, 0, 97, 2, 8],
#       dtype=object)

# %%
master_df.DRINKING.unique()
# Out:
# array([0, 8, 1, 9], dtype=int64)

# %%
# Change values in drinking column
master_df.DRINKING[master_df.DRINKING == 0] = 'No'
master_df.DRINKING[master_df.DRINKING == 1] = 'Yes'
master_df.DRINKING[master_df.DRINKING == 8] = 'Unknown'
master_df.DRINKING[master_df.DRINKING == 9] = 'Unknown'
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create df with helmet data only
helmet_master_df = master_df.loc[(master_df['REST_USE'] == 'Helmet') | (master_df['REST_USE'] == 'No Helmet') | (master_df['REST_USE'] == 'Unknown')]

# %%
helmet_master_df
# Out:
#        Unnamed: 0  ST_CASE  PERSONS  COUNTY  CITY  DAY  MONTH  YEAR  \
# 0               0   480024        2       7     0    4      1  2018
# 3               4   480041        3     439   260    5      1  2018
# 4               5   480044        2      27  3690    6      1  2018
# 5               6   480044        2      27  3690    6      1  2018
# 6               7   480044        2      27  3690    6      1  2018
# ...           ...      ...      ...     ...   ...  ...    ...   ...
# 13395         270   482800        6      61     0   28     11  1998
# 13396         271   482800        6      61     0   28     11  1998
# 13402         279   482844        1     201  3280    6     12  1998
# 13403         280   482860        1      29  6090    9     12  1998
# 13417         298   483021        1      85  5730   29     10  1998
#
#         DAY_WEEK  HOUR  ...  ALIGNMNT  PROFILE PAVE_TYP SUR_COND  TRA_CONT  \
# 0       Thursday    18  ...       NaN      NaN      NaN      NaN       NaN
# 3         Friday    20  ...       NaN      NaN      NaN      NaN       NaN
# 4       Saturday    20  ...       NaN      NaN      NaN      NaN       NaN
# 5       Saturday    20  ...       NaN      NaN      NaN      NaN       NaN
# 6       Saturday    20  ...       NaN      NaN      NaN      NaN       NaN
# ...          ...   ...  ...       ...      ...      ...      ...       ...
# 13395   Saturday    11  ...       2.0      1.0      2.0      1.0       0.0
# 13396   Saturday    11  ...       2.0      1.0      2.0      1.0       0.0
# 13402     Sunday    22  ...       1.0      1.0      1.0      1.0       0.0
# 13403  Wednesday     2  ...       1.0      1.0      2.0      1.0       0.0
# 13417   Thursday     0  ...       2.0      1.0      1.0      1.0      40.0
#
#        T_CONT_F HIT_RUN  C_M_ZONE  latitude longitud
# 0           NaN     NaN       NaN       NaN      NaN
# 3           NaN     NaN       NaN       NaN      NaN
# 4           NaN     NaN       NaN       NaN      NaN
# 5           NaN     NaN       NaN       NaN      NaN
# 6           NaN     NaN       NaN       NaN      NaN
# ...         ...     ...       ...       ...      ...
# 13395       0.0     0.0       0.0       NaN      NaN
# 13396       0.0     0.0       0.0       NaN      NaN
# 13402       0.0     0.0       0.0       NaN      NaN
# 13403       0.0     0.0       0.0       NaN      NaN
# 13417       3.0     0.0       0.0       NaN      NaN
#
# [6046 rows x 51 columns]

# %%
master_df
# Out:
#        Unnamed: 0  ST_CASE  PERSONS  COUNTY  CITY  DAY  MONTH  YEAR  \
# 0               0   480024        2       7     0    4      1  2018
# 1               1   480024        2       7     0    4      1  2018
# 2               2   480041        3     439   260    5      1  2018
# 3               4   480041        3     439   260    5      1  2018
# 4               5   480044        2      27  3690    6      1  2018
# ...           ...      ...      ...     ...   ...  ...    ...   ...
# 13421         302   483068        1     141  2190   19     12  1998
# 13422         303   483113        2     201     0    7     10  1998
# 13423         304   483113        2     201     0    7     10  1998
# 13424         305   483167        3     113  2590   10      7  1998
# 13425         306   483167        3     113  2590   10      7  1998
#
#         DAY_WEEK  HOUR  ...  ALIGNMNT  PROFILE PAVE_TYP SUR_COND  TRA_CONT  \
# 0       Thursday    18  ...       NaN      NaN      NaN      NaN       NaN
# 1       Thursday    18  ...       NaN      NaN      NaN      NaN       NaN
# 2         Friday    20  ...       NaN      NaN      NaN      NaN       NaN
# 3         Friday    20  ...       NaN      NaN      NaN      NaN       NaN
# 4       Saturday    20  ...       NaN      NaN      NaN      NaN       NaN
# ...          ...   ...  ...       ...      ...      ...      ...       ...
# 13421   Saturday    21  ...       1.0      1.0      2.0      1.0       0.0
# 13422  Wednesday    13  ...       1.0      1.0      1.0      1.0       0.0
# 13423  Wednesday    13  ...       1.0      1.0      1.0      1.0       0.0
# 13424     Friday    21  ...       1.0      1.0      2.0      1.0       0.0
# 13425     Friday    21  ...       1.0      1.0      2.0      1.0       0.0
#
#        T_CONT_F HIT_RUN  C_M_ZONE  latitude longitud
# 0           NaN     NaN       NaN       NaN      NaN
# 1           NaN     NaN       NaN       NaN      NaN
# 2           NaN     NaN       NaN       NaN      NaN
# 3           NaN     NaN       NaN       NaN      NaN
# 4           NaN     NaN       NaN       NaN      NaN
# ...         ...     ...       ...       ...      ...
# 13421       0.0     0.0       0.0       NaN      NaN
# 13422       0.0     0.0       0.0       NaN      NaN
# 13423       0.0     0.0       0.0       NaN      NaN
# 13424       0.0     0.0       0.0       NaN      NaN
# 13425       0.0     0.0       0.0       NaN      NaN
#
# [13426 rows x 51 columns]

# %%
# write stacked df to csv file
master_fatal.to_csv('../../Cleaned/MASTER_fatalOnly.csv')

# %%
# write stacked df to csv file
master_df.to_csv('../../Cleaned/MASTER_forPlots.csv')

# %%
# write stacked df to csv file
helmet_master_df.to_csv('../../Cleaned/MASTER_forhelmet.csv')
